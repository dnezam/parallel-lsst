# %%
import networkit as nk
import networkx as nx

# %%
g_i = nk.readGraph('/workspaces/low-avg-stretch/inputs/ErdosRenyi/ErdosRenyi_10_34_GML', nk.Format.GML)
g_o = nk.readGraph('/workspaces/low-avg-stretch/inputs/ErdosRenyi/ErdosRenyi_10_34_GMLgbbs::LowAvgStretch_Algo_Spanner_Runner_0', nk.Format.GML)

# %%
g_i = nk.nxadapter.nk2nx(g_i)
g_o = nk.nxadapter.nk2nx(g_o)

# %%
import matplotlib.pyplot as plt
subax1 = plt.subplot(121)
nx.draw(g_i, with_labels=True)
subax2 = plt.subplot(122)
nx.draw(g_o, with_labels=True)

# %%
nx.find_cycle(g_o)
# Out:
# [(0, 1), (1, 16), (16, 2), (2, 19), (19, 0)]
